# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnu0414/course-enrollment-analyzer/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cd2bc43b-19fb-4ca2-ad0c-ae58bce2ec97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd2bc43b-19fb-4ca2-ad0c-ae58bce2ec97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("heart_failure_clinical_records_dataset.csv")
df.head(10)
#1st question
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
# 7  60.0        1                       315         1                 60
# 8  65.0        0                       157         0                 65
# 9  80.0        1                       123         0                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# ...

# %%
df.shape
# Out:
# (299, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df['age'].mean()
# Out:
# np.float64(60.83389297658862)

# %%
df[df['diabetes']==1].shape[0]
# Out:
# 125

# %%
df['ejection_fraction'].min()
# Out:
# 14

# %%
df['ejection_fraction'].max()
# Out:
# 80

# %%
df[['serum_creatinine','DEATH_EVENT']].mean()
# Out:
# serum_creatinine    1.39388
# DEATH_EVENT         0.32107
# dtype: float64

# %%
df[['high_blood_pressure','smoking']].count()
# Out:
# high_blood_pressure    299
# smoking                299
# dtype: int64

# %%
df.groupby('sex')['age'].mean()
# Out:
# sex
# 0    59.777781
# 1    61.405500
# Name: age, dtype: float64

# %%
df['creatinine_phosphokinase'].nlargest(5)
# Out:
# 1      7861
# 60     7702
# 72     5882
# 103    5209
# 134    4540
# Name: creatinine_phosphokinase, dtype: int64

# %%
df['age_group'] = pd.cut(df['age'], bins =[0,40,60,float('inf')], labels=['young','middle','old'])
df['age_group'].head()
# Out:
# 0       old
# 1    middle
# 2       old
# 3    middle
# 4       old
# Name: age_group, dtype: category
# Categories (3, object): ['young' < 'middle' < 'old']

# %%
df[df['diabetes']==1]['DEATH_EVENT'].mean() * 100
# Out:
# np.float64(32.0)

# %%
df[df['serum_sodium'] <130]
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 1    55.0        0                      7861         0                 38
# 3    50.0        1                       111         0                 20
# 5    90.0        1                        47         0                 40
# 6    75.0        1                       246         0                 15
# 7    60.0        1                       315         1                 60
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.groupby('DEATH_EVENT')[['age','ejection_fraction']].mean()
# Out:
#                    age  ejection_fraction
# DEATH_EVENT
# 0            58.761906           40.26601
# 1            65.215281           33.46875

# %%
df[['serum_creatinine','DEATH_EVENT']].corr()
# Out:
#                   serum_creatinine  DEATH_EVENT
# serum_creatinine          1.000000     0.294278
# DEATH_EVENT               0.294278     1.000000

# %%
d = df.pivot_table(values='ejection_fraction', index='sex', columns='DEATH_EVENT', aggfunc='mean')
d
# Out:
# DEATH_EVENT          0          1
# sex
# 0            41.873239  37.529412
# 1            39.401515  31.241935

# %%
df[(df['age'] > 60) & (df['diabetes']) & (df['high_blood_pressure'])]
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 21   65.000        1                       128         1                 30
# 24   75.000        0                       582         1                 30
# 27   70.000        0                       122         1                 45
# 30   94.000        0                       582         1                 38
# 34   65.000        0                        94         1                 50
# 37   82.000        1                       855         1                 50
# 42   70.000        0                       571         1                 45
# 43   72.000        0                       127         1                 50
# 53   70.000        1                        69         1                 50
# 59   72.000        0                       364         1                 20
# 78   75.000        1                       203         1                 38
# ...

# %%
df.sort_values(by="time", ascending=False)[df['DEATH_EVENT']==1].tail(10)
# Out:
# /tmp/ipython-input-933222886.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.sort_values(by="time", ascending=False)[df['DEATH_EVENT']==1].tail(10)
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 10  75.0        1                        81         0                 38
# 6   75.0        1                       246         0                 15
# 9   80.0        1                       123         0                 35
# 11  62.0        0                       231         0                 25
# 5   90.0        1                        47         0                 40
# 4   65.0        1                       160         1                 20
# 3   50.0        1                       111         0                 20
# 2   65.0        0                       146         0                 20
# 1   55.0        0                      7861         0                 38
# ...

# %%
df['platelets_normalized'] = (df['platelets'] - df['platelets'].min()) / (df['platelets'].max() - df['platelets'].min())
df[['platelets', 'platelets_normalized']].head()
# Out:
#    platelets  platelets_normalized
# 0  265000.00              0.290823
# 1  263358.03              0.288833
# 2  162000.00              0.165960
# 3  210000.00              0.224148
# 4  327000.00              0.365984
